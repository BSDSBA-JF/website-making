# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
areas = np.pi * (15 * np.random.rand(N)) ** 2
plt.scatter(x, y, s=areas, c=colors, alpha=0.2)
plt.show()

# %%
# %%HTML
# <iframe width="560 " height="315 " src="https://www.youtube.com/embed/YJC6ldI3hWk" frameborder="0" allowfullscreen></iframe >
# Out:
# <iframe width="560 " height="315 " src="https://www.youtube.com/embed/YJC6ldI3hWk" frameborder="0" allowfullscreen></iframe >

# %%
# %%latex
# \usepackage{hyperref}
#
# To capture the presence of individual Pokémon across episodes in the animated series, episode data was scraped from \href{https://bulbapedia.bulbagarden.net/wiki/List_of_animated_series_episodes}{Bulbapedia’s animated series episode list}. The scraping process began by accessing the Bulbapedia page containing links to episode tables organized by narrative arcs. These tables were parsed to extract individual episode links, which were then concatenated into a complete list of episode URLs. For each episode page, the script located the “Pokémon” section, marked by \texttt{<span id="Pokémon">}, and extracted the following \texttt{<ul>} list of appearing Pokémon as show in Figure \ref{fig:2_anime_webscrape}. Names were cleaned with regular expressions to remove trailing descriptors for alternate forms. A binary presence matrix was created, marking 1 for appearance and 0 otherwise, and organized into a structured dictionary. The anime dataset was exported for later use.
# Out:
# \usepackage{hyperref}
#
# ...

# %%
# %%timeit
squares = [n ** 2 for n in range(100)]
# Out:
# 3.17 μs ± 48.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
